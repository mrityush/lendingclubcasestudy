# %% [markdown]
# ### LendingClub Case Study

# %% [markdown]
# #### importing the needed libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - Read the csv from location

# %%
loan_data_df = pd.read_csv('Case Study Notebook/loan.csv')
# Out:
# /tmp/ipykernel_62127/160526682.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_data_df = pd.read_csv('Case Study Notebook/loan.csv')
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# ...

# %% [markdown]
# - Check the rows values at head, so that we have a hint of information that we are going to process

# %%
loan_data_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %% [markdown]
# - Check shape of the datatable, and description

# %%
loan_data_df.shape
# Out:
# (39717, 111)

# %%
loan_data_df.describe()

# %% [markdown]
# - Check dtypes of the loan datatable

# %%
loan_data_df.dtypes
# Out:
# id                       int64
# member_id                int64
# loan_amnt                int64
# funded_amnt              int64
# funded_amnt_inv        float64
#                         ...
# num_op_rev_tl          float64
# num_rev_accts          float64
# num_rev_tl_bal_gt_0    float64
# num_sats               float64
# num_tl_120dpd_2m       float64
# Length: 100, dtype: object

# %% [markdown]
# I can not see all columns data types so I will have to seek some other way to confirm different datatypes of fields

# %%
## code to check all datatypes

# %% [markdown]
# - ##### Important thing to note after importing: the columns have mixed types. So we have to do data cleaning first
